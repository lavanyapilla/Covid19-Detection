# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.layers import *
from keras.models import Sequential
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir("/content/drive/MyDrive/Covid-19-Detection")

# %%
model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),activation='relu',
           input_shape=(224,224,3)))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128,activation='relu'))

model.add(Dropout(0.25))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
train_datagen = image.ImageDataGenerator(rescale = 1./255,
                                         width_shift_range=0.1,
                         		             height_shift_range=0.1,
                                         shear_range = 0.2,
                                         zoom_range = 0.2,
                                         horizontal_flip = True)

test_datagen = image.ImageDataGenerator(rescale=1./255)

# %%
 
train_generator = train_datagen.flow_from_directory(
    'Dataset/Train',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary')
validation_generator = test_datagen.flow_from_directory(
    'Dataset/Valid',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary')
# Out:
# Found 224 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
his = model.fit(
    train_generator,
    steps_per_epoch=5,
    epochs = 20,
    validation_data = validation_generator,
    validation_steps=2
)
# Out:
# Epoch 1/20
# 5/5 [==============================] - 10s 2s/step - loss: 7.2473 - accuracy: 0.5335 - val_loss: 0.6663 - val_accuracy: 0.5333
# Epoch 2/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.6428 - accuracy: 0.6069 - val_loss: 0.6508 - val_accuracy: 0.6333
# Epoch 3/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.6020 - accuracy: 0.6217 - val_loss: 0.4235 - val_accuracy: 0.9167
# Epoch 4/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.4260 - accuracy: 0.8413 - val_loss: 0.2586 - val_accuracy: 0.9167
# Epoch 5/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.3554 - accuracy: 0.8629 - val_loss: 0.2477 - val_accuracy: 0.9500
# Epoch 6/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.4152 - accuracy: 0.8301 - val_loss: 0.2234 - val_accuracy: 0.9500
# Epoch 7/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.2329 - accuracy: 0.9188 - val_loss: 0.1409 - val_accuracy: 0.9667
# Epoch 8/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1989 - accuracy: 0.9382 - val_loss: 0.0903 - val_accuracy: 0.9833
# Epoch 9/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.2161 - accuracy: 0.9312 - val_loss: 0.1176 - val_accuracy: 0.9500
# Epoch 10/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1944 - accuracy: 0.9167 - val_loss: 0.1096 - val_accuracy: 0.9667
# Epoch 11/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1607 - accuracy: 0.9212 - val_loss: 0.0989 - val_accuracy: 0.9667
# Epoch 12/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1753 - accuracy: 0.9451 - val_loss: 0.1161 - val_accuracy: 0.9667
# Epoch 13/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1729 - accuracy: 0.9595 - val_loss: 0.0939 - val_accuracy: 0.9500
# Epoch 14/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1424 - accuracy: 0.9341 - val_loss: 0.1042 - val_accuracy: 0.9667
# Epoch 15/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1745 - accuracy: 0.9270 - val_loss: 0.0897 - val_accuracy: 0.9500
# Epoch 16/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.2137 - accuracy: 0.9075 - val_loss: 0.0855 - val_accuracy: 0.9833
# Epoch 17/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1778 - accuracy: 0.9144 - val_loss: 0.0765 - val_accuracy: 0.9667
# Epoch 18/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1756 - accuracy: 0.9275 - val_loss: 0.0627 - val_accuracy: 0.9833
# Epoch 19/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1364 - accuracy: 0.9510 - val_loss: 0.0605 - val_accuracy: 0.9833
# Epoch 20/20
# 5/5 [==============================] - 8s 2s/step - loss: 0.1320 - accuracy: 0.9450 - val_loss: 0.1025 - val_accuracy: 0.9333

# %%
# loss
plt.plot(his.history['loss'], label='train loss')
plt.plot(his.history['val_loss'], label='val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Loss Comparison Graph")
plt.legend()
plt.show()
plt.savefig('loss')

# accuracies
plt.plot(his.history['accuracy'], label='train acc')
plt.plot(his.history['val_accuracy'], label='val acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Accuracy Comparison Graph")
plt.legend()
plt.show()
plt.savefig('Accuracy')

# %%
model.save("covid_detector.h5")

# %%
import tensorflow 
from tensorflow.keras.models import load_model

model = load_model("covid_detector.h5")

# %%
def preprocess_image(image):
  img = cv2.resize(image,(224,224))

  img = img.astype("float") / 255.0
  img = img_to_array(img)
  img = np.expand_dims(img,axis=0)

  return img

# %%
import cv2

img1 = cv2.imread("fig1.png")
img2 = cv2.imread("fig2.jpeg")

#defining classes 
classes = ['covid_infected','Normal']

prep_img = preprocess_image(img2)

# model prediction
result = model.predict(prep_img)

## get label with max accuracy
if result>0.5:
  label = 1
else:
  label=0


label_name = classes[label]

plt.figure()
plt.imshow(img2)
plt.title('{} '.format(label_name))
plt.savefig("fig2_res")
plt.show()
